# %% [markdown]
# # DFTTK Example for AlNi

# %% [markdown]
# ## Introduction

# %%
! dfttk -h
# Out:
# DFTTK version: 0.3.4+8.g7f57cf0
# Copyright © Phases Research Lab (https://www.phaseslab.com/)
#
# usage: dfttk [-h] {run,config,db_remove,thelec,thfind,EVfind} ...
#
# Run DFTTK jobs.
#
# positional arguments:
#   {run,config,db_remove,thelec,thfind,EVfind}
#     run                 Run dfttk.
#     config              Config dfttk.
#     db_remove           Remove data in MongoDb.
#     thelec              Postprocess DFTTK results after DFT job completed.
#     thfind              Check the dfttk DFT calculation results followed by
#                         calling the 'thelec' module to get thermodynamic
#                         properties when the option '-get' is given.
#     EVfind              Find the metadata tags that have 0 K static calculaton
#                         finished.
#
# optional arguments:
#   -h, --help            show this help message and exit

# %% [markdown]
# ## Run DFTTK
#
# ### Input
# * Structure file of AlNi (POSCAR.AlNi)
#
# ```
# Al1 Ni1
# 1.0
# 2.887902 0.000000 0.000000
# 0.000000 2.887902 0.000000
# 0.000000 0.000000 2.887902
# Al Ni
# 1 1
# direct
# 0.000000 0.000000 0.000000 Al
# 0.500000 0.500000 0.500000 Ni
# ```
# * Setting file (SETTINGS.yaml)
#
# ```yaml
# phonon : True
# phonon_supercell_matrix : [[0, 2, 2], [2, 0, 2], [2, 2, 0]]
# ```
# Prepare POSCAR and SETTINGS.yaml file and put them in the same directory. Then run following commands to start the workflow.

# %% [markdown]
# ### DFTTK run module

# %% [markdown]
# Use `-wf` to specify the workflow to run, here we use `robust` workflow. Use `-f` to specify the strucutre file, here the name of the structure file is `POSCAR`. Use `-s` to specify the setting file, here the setting file is `SETTINGS.yaml`. Use -l to launch the workflow to launchpad. For more options, please refer to `dfttk run -h`

# %%
! dfttk run -wf robust -f POSCAR.AlNi -s SETTINGS -l
# Out:
# DFTTK version: 0.3.4+8.g7f57cf0
# Copyright © Phases Research Lab (https://www.phaseslab.com/)
#
# 2021-10-15 09:47:50,005 INFO Added a workflow. id_map: {-4: 6338, -3: 6339, -2: 6340, -1: 6341}

# %% [markdown]
# To launch the DFT batch job in the computers that VASP installed, you can use `qlaunch singleshot`

# %% [markdown]
# To manage workflow and check the status of your work, you can use `lpad` command. For more options, please refer to `lpad -h`

# %%
! lpad get_wflows -s READY
# Out:
# []

# %% [markdown]
# ## Plot thermodynamic properties

# %% [markdown]
# Use `dfttk thfind` to check the completed task.

# %%
! dfttk thfind
# Out:
# DFTTK version: 0.3.4+8.g7f57cf0
# Copyright © Phases Research Lab (https://www.phaseslab.com/)
#
#
# found complete calculations in the collection: phonon
#
# {'tag': '428621f2-f44f-4c92-b307-04a89c77da5f'}, phonon: 13, static: 13, SN:  16, qha_phonon: T, ZnPd_P4.mmm_123PBE
# {'tag': 'a715a62f-bfa7-4d95-bffb-41d56865c488'}, phonon: 13, static: 13, SN:  16, qha_phonon: T, ZnPd_P4.mmm_123PBE#0
# {'tag': '6b23d6a5-d15c-46de-be2f-f021159e852d'}, phonon:  8, static:  8, SN:  52, qha_phonon: T, Zn8Pd5_I-43m_217PBE
# {'tag': 'fa5e4e62-91b0-4c62-acff-26ae851da38b'}, phonon:  9, static:  9, SN:  33, qha_phonon: T, ZnPd10_P-1_2PBE_FM
# {'tag': '76dd7e4c-9c8e-4f8e-8083-b4aaa6218eb9'}, phonon:  8, static:  8, SN:  27, qha_phonon: F, ZnPd8_P-31m_162PBE_FM
# {'tag': '3c01629a-b287-41f5-8826-d77912f54177'}, phonon:  7, static:  8, SN:  64, qha_phonon: T, Al_Fm-3m_225PBE
# {'tag': 'db521c56-bd17-4b15-9887-ff964f0c6f7c'}, phonon:  7, static:  7, SN:  90, qha_phonon: T, Al3Ru2_I4.mmm_139PBE
# {'tag': '48623a91-47ac-4054-b46b-2e23c3f82bff'}, phonon:  8, static:  8, SN:  40, qha_phonon: T, Al3Ru2_P-3m1_164PBE#0
# {'tag': '6af91aef-5034-4fc2-a4d3-69b68f3d41ac'}, phonon:  7, static:  7, SN:  54, qha_phonon: T, AlRu_Pm-3m_221PBE
# {'tag': 'e946153c-a542-4293-a1a2-be9b143f16b7'}, phonon:  8, static:  8, SN:  56, qha_phonon: T, Al6Ru_Cmcm_63PBE
# {'tag': '9746b356-75e4-474a-acce-f297c1fabef2'}, phonon:  7, static:  7, SN:  96, qha_phonon: T, Al2Ru_Fddd_70PBE
# {'tag': '86ffaca5-6695-45b2-94a8-381d317355a3'}, phonon:  7, static:  7, SN: 128, qha_phonon: T, Ru_P6_3.mmc_194PBE#0
# {'tag': '8427ba90-3181-4632-aa49-5823d4aa5082'}, phonon:  8, static:  8, SN: 108, qha_phonon: T, Ni_Fm-3m_225PBE_FM
# {'tag': 'e04d822a-a11a-4705-a9b4-f32d24d0b807'}, phonon:  7, static:  7, SN:  32, qha_phonon: T, AlNi_Pm-3m_221PBE
#
# 13/18 qha_phonon successful under the given searching conditions.

# %% [markdown]
# Check the tag for the workflow for AlNi. Then use `dfttk thfind` to plot all thermodynamic properties based on DFTTK results. For more options, please refer to ` dfttk thfind -h`

# %%
! dfttk thfind -tag e04d822a-a11a-4705-a9b4-f32d24d0b807 -get -plot DFTTK -renew -expt ExptData.json
# Out:
# DFTTK version: 0.3.4+8.g7f57cf0
# Copyright © Phases Research Lab (https://www.phaseslab.com/)
#
#
# found complete calculations in the collection: phonon
#
# {'tag': 'e04d822a-a11a-4705-a9b4-f32d24d0b807'}, phonon:  7, static:  7, SN:  32, qha_phonon: T, AlNi_Pm-3m_221PBE
#
# 1/1 qha_phonon successful under the given searching conditions.
#
# Downloading data by metadata tag: e04d822a-a11a-4705-a9b4-f32d24d0b807
#
# Postprocess for thermodynamic properties, Seebeck, Lorenz number etc.
#
# Full Formula (Al1 Ni1)
# Reduced Formula: AlNi
# abc   :   3.025995   3.025995   3.025995
# angles:  90.000000  90.000000  90.000000
# Sites (2)
#   #  SP      a    b    c    magmom
# ---  ----  ---  ---  ---  --------
#   0  Al    0    0    0           0
#   1  Ni    0.5  0.5  0.5        -0
#
#
# niggli reduced structure Full Formula (Al1 Ni1)
# Reduced Formula: AlNi
# abc   :   3.025995   3.025995   3.025995
# angles:  90.000000  90.000000  90.000000
# Sites (2)
#   #  SP      a    b    c    magmom
# ---  ----  ---  ---  ---  --------
#   0  Al    0    0    0           0
#   1  Ni    0.5  0.5  0.5        -0
#
#
# found volumes from static calculations: [20.47978633 21.68449561 22.88917694 24.09387215 25.29856939 26.5032539
#  27.70796423]
#
# vasp version for the static calculation is: 5.4.1  for  e04d822a-a11a-4705-a9b4-f32d24d0b807
#
#
# Trying to get quasiharmonic mode : phonon...
#
# Checking compatibility between qha/Yphon data and static calculation:
#
# [20.47978633 21.68449561 22.88917694 24.09387215 25.29856939 26.5032539
#  27.70796423]
# 20.479786334687127 -10.16257242
# 21.684495608404713 -10.38845038
# 22.889176936014383 -10.50905254
# 24.09387215155318 -10.54913439
# 25.298569390189137 -10.52768447
# 26.50325390334201 -10.45911379
# 27.70796422608695 -10.35462884
#
# OK, I found some data that I can try
#
# #Bandgap= 0.0 eV at volume= 20.479786334687127 Angstrom^3/cell. Fermi energy was shifted 0.0 due to doping of 0 resulting Ne=12.97098315296429
# #Bandgap= 0.0 eV at volume= 21.684495608404713 Angstrom^3/cell. Fermi energy was shifted 0.0 due to doping of 0 resulting Ne=12.95884992690866
# #Bandgap= 0.0 eV at volume= 22.889176936014383 Angstrom^3/cell. Fermi energy was shifted 0.0 due to doping of 0 resulting Ne=12.972677595819713
# #Bandgap= 0.0 eV at volume= 24.09387215155318 Angstrom^3/cell. Fermi energy was shifted 0.0 due to doping of 0 resulting Ne=13.00453155201809
# #Bandgap= 0.0 eV at volume= 25.298569390189137 Angstrom^3/cell. Fermi energy was shifted 0.0 due to doping of 0 resulting Ne=12.941458501127581
# #Bandgap= 0.0 eV at volume= 26.50325390334201 Angstrom^3/cell. Fermi energy was shifted 0.0 due to doping of 0 resulting Ne=12.976965935404841
# #Bandgap= 0.0 eV at volume= 27.70796422608695 Angstrom^3/cell. Fermi energy was shifted 0.0 due to doping of 0 resulting Ne=12.97454822792136
#
# blat<0! Perhaps it has reached the upvolume limit at T = 1225
#
#
# blat<0! Perhaps it has reached the upvolume limit at T = 1225
#
#
# Full thermodynamic properties have outputed into: AlNi_Pm-3m_221PBE/fvib_ele
# All figures will be outputed into:  AlNi_Pm-3m_221PBE/figures   with T uplimt: None
#
# Enjoy!
#
# {
#     "Cp (J/mol-atom/K)": "Cp(T) = +38.9762 -0.0376195*T +3.79769e-05*T*T -650482/T/T",
#     "G-H298.15 (J/mol-atom)": "G(T) = -12491.2 +228.427*T -38.9762*T*log(T) +0.0188097*T*T -6.32949e-06*T*T*T +325241/T",
#     "H-H298.15 (J/mol-atom)": "H(T) = -12491.2 +38.9762*T -0.0188097*T*T +1.2659e-05*T*T*T +650482/T",
#     "S (J/mol-atom/K)": "S(T) = -189.45 +38.9762*log(T) -0.0376195*T +1.89885e-05*T*T +325241/T/T",
#     "fitting uncertainty": 1.4
# }

# %%
! dfttk thfind -h
# Out:
# DFTTK version: 0.3.4+8.g7f57cf0
# Copyright © Phases Research Lab (https://www.phaseslab.com/)
#
# usage: dfttk thfind [-h] [-w [WITHIN]] [-all [CONTAINALL]]
#                     [-xall [EXCLUDEALL]] [-xany [EXCLUDEANY]]
#                     [-any [CONTAINANY]] [-v [NV]] [-poisson [POISSON]]
#                     [-ss [SUPERCELLN]] [-fg] [-get] [-db [DB_FILE]] [-check]
#                     [-remove] [-py] [-T0 [T0]] [-dgx [DEBYE_GRUNEISEN_X]]
#                     [-db_repair] [-db_renew] [-T1 [T1]] [-dT [TD]]
#                     [-xdn [XDN]] [-xup [XUP]] [-dope [DOPE]] [-ne [NDOSMX]]
#                     [-gauss [GAUSSIAN]] [-natom [NATOM]] [-l [LOCAL]]
#                     [-nT [NT]] [-e [EVERYT]] [-o [OUTF]] [-noel]
#                     [-tag [METATAG]] [-qhamode [QHAMODE]] [-pn [PHASENAME]]
#                     [-jp [JOBPATH]] [-kpm [K_PH_MODE]] [-eq [EQMODE]]
#                     [-el [ELMODE]] [-s] [-plot [PLOT]] [-renew] [-refresh]
#                     [-fitCp] [-fitF] [-po] [-g] [-expt [EXPT]] [-xlim [XLIM]]
#                     [-dos [DOSCAR]] [-pos [POSCAR]] [-vdos [VDOS]]
#
# optional arguments:
#   -h, --help            show this help message and exit
#   -w [WITHIN], --within [WITHIN]
#                         find calculations within element list Default: None
#   -all [CONTAINALL], --containall [CONTAINALL]
#                         find calculations must contain all elements in the
#                         list Default: None
#   -xall [EXCLUDEALL], --excludeall [EXCLUDEALL]
#                         exclude calculations that conain all elements in the
#                         list Default: None
#   -xany [EXCLUDEANY], --excludeany [EXCLUDEANY]
#                         exclude calculations that conain any elements in the
#                         list Default: None
#   -any [CONTAINANY], --containany [CONTAINANY]
#                         find calculations contain any elements in the list
#                         Default: None
#   -v [NV], --nV [NV]    Return phonon calculations finished for number of
#                         volumes larger or equals to. Default: 6
#   -poisson [POISSON], --poisson_ratio [POISSON]
#                         Poisson ratio used for Dybye model, if default, wiil
#                         set to 0.363615. Default: 60.363615
#   -ss [SUPERCELLN], --supercellsize [SUPERCELLN]
#                         only return phonon calculation with supercell size
#                         larger than. Default: 0
#   -fg, --findbandgap    report the entries with band gap. Default: False
#   -get, --get           call thelec module to get the thermodyamic data for
#                         all found entries. Default: False
#   -db [DB_FILE], --db_file [DB_FILE]
#                         alternative database other than default Default: None
#   -check, --check       check database. Default: False
#   -remove, --remove     remove database document entries under given
#                         conditions (under development). Default: False
#   -py, --pyphon         use Yphon to recalculate vibrational properties.
#                         Default: False
#   -T0 [T0], -t0 [T0]    Low temperature limit. Default: 0
#   -dgx [DEBYE_GRUNEISEN_X], --debye_gruneisen_x [DEBYE_GRUNEISEN_X]
#                         Value of x for the Debye gruneisen model. Default: 2/3
#   -db_repair, --db_repair
#                         repair database for prebiously FIZZLED calculation.
#                         Default: False
#   -db_renew, --db_renew
#                         renew the database. Default: False
#   -T1 [T1], -t1 [T1]    High temperature limit. Default: 4000
#   -dT [TD], -td [TD]    Temperature increment. Default: 10
#   -xdn [XDN], --xdn [XDN]
#                         Low band energy limit. Default: -100 (eV)
#   -xup [XUP], --xup [XUP]
#                         High band energy limit. Default: 100
#   -dope [DOPE], --dope [DOPE]
#                         dope level (electrons). Default: 0, change it to -1e-5
#                         can speed up the calculation while it may destropy the
#                         numerical stability
#   -ne [NDOSMX], --ndosmx [NDOSMX]
#                         new eDOS mesh. It recommend increase it 100001 if
#                         numberical instability seen. Default: 10001 if dope
#                         >5.e-9 or 100001
#   -gauss [GAUSSIAN], --gauss [GAUSSIAN]
#                         densing factor for eDOS mesh near the Fermi energy.
#                         Default: 1000
#   -natom [NATOM], --natom [NATOM]
#                         number of atoms in the DOSCAR. Default: 1
#   -l [LOCAL], --local [LOCAL]
#                         path holding all input for Yphon. Default: blank
#   -nT [NT], --nT [NT]   number of temperatures, used together with -td -50.
#                         Default: 257
#   -e [EVERYT], --everyT [EVERYT]
#                         number of temperature points skipped from QHA analysis
#                         from the qha/qha_phonon collection. Default: 1
#   -o [OUTF], -outf [OUTF]
#                         output filename for calculated thermoelectric
#                         properties. Default: fvib_ele
#   -noel, -noel          do not consider the thermal electron contribution.
#                         Default: False
#   -tag [METATAG], --metatag [METATAG]
#                         metatag: MongoDB metadata tag field. Default: None
#   -qhamode [QHAMODE], -qhamode [QHAMODE]
#                         quasiharmonic mode: debye, phonon, or yphon. Default:
#                         None
#   -pn [PHASENAME], -phasename [PHASENAME]
#                         assigan phase name. Default: None
#   -jp [JOBPATH], -jobpath [JOBPATH]
#                         For debug/development purpoase. Parent path where jobs
#                         were submittedi to check settings. Default: None
#   -kpm [K_PH_MODE], --k_ph_mode [K_PH_MODE]
#                         Mode to calculate thermal conductivity using slack
#                         model. 2: Original model, using the Debye T calc. at
#                         lowest T; 1: using thermodynamic gruneisen gamma and
#                         T-dependent debye T; Default: 2
#   -eq [EQMODE], --eqmode [EQMODE]
#                         Mode to calculate equilibrium volume and LTC. 0:
#                         Symmetrical Central differential if the data is
#                         excellent; 4: 4-parameter BM fitting if the data is
#                         faitly good; 5: 5-parameter BM fitting if the data is
#                         very good. Default: 4
#   -el [ELMODE], --elmode [ELMODE]
#                         Mode to interpolate thermal electronic contribution:
#                         0: interp1d; 1: UnivariateSpline. Default: 0
#   -s, -smooth           smooth the LTC. Default: False
#   -plot [PLOT], -plot [PLOT]
#                         plot the figures and mark the theoretial line with the
#                         given label. Default: None
#   -renew, -renew        renew/plot the figure. Otherwise, calculation will be
#                         skipped if the file 'fvib_ele' is seen. Default: False
#   -refresh, -refresh    recalculate the phonon dos. Default: False
#   -fitCp, --SGTEfitCp   report SGTE fitting through the order of Cp, S, and H.
#                         Default: False, report SGTE fitting using Gibbs
#                         energy.
#   -fitF, -fitF          USE with CARE! apply for the case of poor data
#                         quality. Enforce linear fitting to the vibrational and
#                         electronic free energy together enforce 4-parameter
#                         Birch–Murnaghan fitting to the 0 K static energies. A
#                         file named 'fitF' must be set in that phase folder
#                         using 'touch fitF' to make the option take effect.
#                         Note: The regualar run will skip the phase folder if a
#                         file name 'fitF' is seen there. Default: False
#   -po, --plotonly       No calculations, only plot the calulcated results if
#                         any. Default: False
#   -g, --debug           turn on debug mode by reducing the mesh. Default:
#                         False
#   -expt [EXPT], -expt [EXPT]
#                         file path (json format, list of dictionary) for
#                         experimental thermodynamic properties to be compared
#                         with. Default: None
#   -xlim [XLIM], -xlim [XLIM]
#                         Up temperature limit for plot. Default: None
#   -dos [DOSCAR], --doscar [DOSCAR]
#                         file path to DOSCAR file. Run thelec in single volume
#                         shot only. Default: None
#   -pos [POSCAR], --poscar [POSCAR]
#                         file path to POSCAR file. Run thelec in single volume
#                         shot only. Default: None
#   -vdos [VDOS], --vdos [VDOS]
#                         file path to phonon DOS file produced by Yphon. Run
#                         thelec in single volume shot only. Default: None

# %% [markdown]
# The figures are in folder `AlNi_Pm-3m_221PBE/figures`

# %%
import os
import matplotlib.image as im
import matplotlib.pyplot as plt
# %matplotlib inline
path_name='AlNi_Pm-3m_221PBE/figures'
for item in os.listdir(path=path_name):
    print(item)
    img = im.imread(os.path.join(path_name,item))
    plt.imshow(img)
    plt.show()
# Out:
# Heat_capacities_300.png
# Bulk_modulus.png
# LTC.png
# Effective_charge_carrier_concentration_100.png
# Heat_capacities_1000_oT2.png
# Lorenz_number.png
# Gibbs_energy-H298.png
# Debye_temperature.png
# Heat_capacities_100_oT2.png
# Seebeck_coefficients.png
# Effective_charge_carrier_concentration.png
# Absolute_thermal_electric_force.png
# Gruneisen_coefficient.png
# 0_K_total_energies.png
# Debye_temperature_70.png
# Enthalpy-H298.png
# Heat_capacities_300_el_oT.png
# Atomic_volume.png
# Entropy.png
# Heat_capacities.png

# %% [markdown]
# You can also specify the figure that you would like to plot.

# %%
path_name='AlNi_Pm-3m_221PBE/figures'
item='Bulk_modulus.png'
img = im.imread(os.path.join(path_name,item))
plt.imshow(img)
plt.show()

# %% [markdown]
# In addtion to figures, original data are generated by `thfind`

# %%
path_name='AlNi_Pm-3m_221PBE/'
os.listdir(path=path_name)
# Out:
# ['fvib_ele',
#  'fvib_ele_sm',
#  '.DS_Store',
#  'record.json',
#  'Yphon',
#  'POSCAR',
#  'readme',
#  'fvib_eij',
#  'figures']
